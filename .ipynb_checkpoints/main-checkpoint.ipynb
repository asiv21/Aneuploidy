# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
B1_IO = pd.read_csv('Data/Batch_1/Interval_order.csv')
B1_Depth = pd.read_csv('Data/Batch_1/Depth.csv')

B2_IO = pd.read_csv('Data/Batch_2/Interval_order.csv')
B2_Depth = pd.read_csv('Data/Batch_2/Depth.csv')

# %%
plt.plot(B1_IO['Chrom'])
print(B1_IO.shape, B1_Depth.shape)
# Out:
# ((79451, 3), (79451, 24))

# %%
plt.plot(B2_IO['Chrom'])
print(B2_IO.shape, B2_Depth.shape)
# Out:
# ((79451, 3), (79451, 24))

# %%
plt.plot(B2_Depth)
plt.show()

# %%
B1_IO.head()
# Out:
#    Chrom   Start     End
# 0      1  948903  949006
# 1      1  949313  949413
# 2      1  949414  949513
# 3      1  949514  949613
# 4      1  949614  949713

# %%
B1_IO.loc[B1_IO['Chrom'] == 24]
# Out:
#        Chrom     Start       End
# 73537     24   2649475   2649574
# 73538     24   2649575   2649674
# 73539     24   2654743   2654843
# 73540     24   2654844   2654943
# 73541     24   2654944   2655043
# 73542     24   2655044   2655143
# 73543     24   2655144   2655243
# 73544     24   2655244   2655343
# 73545     24   2655344   2655443
# 73546     24   2655444   2655543
# 73547     24   2655544   2655643
# 73548     24   2655644   2655743
# 73549     24   2655744   2655843
# 73550     24   2655844   2655943
# 73551     24   2655944   2656043
# 73552     24   2656044   2656143
# 73553     24   2656144   2656243
# 73554     24   2656244   2656343
# 73555     24   2656344   2656443
# 73556     24   2656444   2656543
# 73557     24   2656544   2656643
# 73558     24   2656644   2656743
# 73559     24   2656744   2656843
# 73560     24   2656844   2656943
# 73561     24   2656944   2657043
# 73562     24   2657044   2657143
# 73563     24   2657144   2657243
# 73564     24   2657244   2657343
# 73565     24   2657344   2657443
# 73566     24   2657444   2657543
# ...      ...       ...       ...
# 79421     24  28782349  28782433
# 79422     24  28783742  28783842
# 79423     24  28783843  28783942
# 79424     24  28783943  28784042
# 79425     24  28784043  28784142
# 79426     24  28784143  28784242
# 79427     24  28784243  28784402
# 79428     24  28784619  28784719
# 79429     24  28784720  28784819
# 79430     24  28784820  28784919
# 79431     24  28784920  28785019
# 79432     24  28785020  28785119
# 79433     24  28785120  28785239
# 79434     24  28806707  28806807
# 79435     24  28806808  28806957
# 79436     24  58980908  58981008
# 79437     24  58981009  58981134
# 79438     24  59002100  59002239
# 79439     24  59004277  59004377
# 79440     24  59004378  59004477
# 79441     24  59004478  59004577
# 79442     24  59004578  59004677
# 79443     24  59004678  59004761
# 79444     24  59007187  59007287
# 79445     24  59007288  59007426
# 79446     24  59032826  59032926
# 79447     24  59032927  59033026
# 79448     24  59033027  59033126
# 79449     24  59033127  59033226
# 79450     24  59033227  59033326
#
# [5914 rows x 3 columns]

# %%
bounds=[] 
for i in range(1,25): 
    bounds.append((B1_IO.loc[B1_IO['Chrom'] == i].iloc[0].name,B1_IO.loc[B1_IO['Chrom'] == i].iloc[-1].name))

# %%
bounds[0]
# Out:
# (0, 5292)

# %%
counts = np.zeros((24,24)) # Chromosome number (1-23) (on the rows) x sample number (1-24) (on the columns)
for i in range(24):
    counts[i,:] = np.sum(B1_Depth[bounds[i][0]:bounds[i][1]+1]) #watch the notation here bc I think calls one too short for DataFrames 
#B1_Depth.iloc[bounds[0][0]]

# %%
counts[:,0]
# Out:
# array([1998723.7814    , 1793318.2324    , 1464504.2118    ,
#         995364.2441    , 1573355.3504    , 1635308.545     ,
#        1901713.41010001,  814208.4152    , 1229598.8546    ,
#         863341.9744    , 1296392.5281    , 1420397.4586    ,
#         548166.1053    ,  877353.661     , 1066817.9616    ,
#         711136.2002    , 1345010.8483    ,  376478.8181    ,
#        1010328.6676    ,  569938.1903    ,  132479.6137    ,
#         368046.4084    , 1690648.31290004,  892136.10469999])

# %%
B1_Depth.head()
# Out:
#    Sample 01  Sample 02  Sample 03  Sample 04  Sample 05  Sample 06  \
# 0   234.1442   230.4327   274.2212   280.2596   262.3942   228.5865
# 1   160.0693   160.5446   173.6040   154.7129   141.9604   165.9505
# 2   192.9000   195.9500   167.3500   194.6400   175.0500   199.1800
# 3   218.7100   191.4200   178.2400   235.9300   175.7300   227.3400
# 4   279.2100   260.7300   234.9600   308.4200   237.7700   283.7500
#
#    Sample 07  Sample 08  Sample 09  Sample 10    ...      Sample 15  \
# 0   228.3654   162.7500   276.7308   126.1538    ...       183.1442
# 1   158.3663   134.7624   165.4455   114.0792    ...       136.3861
# 2   194.4900   166.7200   189.4400   141.5700    ...       174.1200
# 3   213.2000   195.4900   239.5800   172.6500    ...       203.9700
# 4   277.4100   240.4800   329.4600   198.3500    ...       251.6000
#
#    Sample 16  Sample 17  Sample 18  Sample 19  Sample 20  Sample 21  \
# 0   425.1250   187.2885   256.2788   221.1731   274.4712   205.4135
# 1   259.1485   161.5050   152.1485   134.4455   140.8911   138.1683
# 2   283.6400   205.7100   184.4400   185.2800   176.3700   187.5800
# 3   317.8800   256.9000   217.7800   219.1200   224.5700   199.5700
# 4   443.9100   308.1900   280.0300   247.7200   282.9200   212.6700
#
#    Sample 22  Sample 23  Sample 24
# 0   203.7019   197.6250   245.7500
# 1   105.9703   121.5644   166.2079
# 2   111.7700   127.1400   210.8800
# 3    93.3600   155.5800   244.3400
# 4   146.7200   207.1300   290.3700
#
# [5 rows x 24 columns]

# %%
print(B1_IO.shape, B1_Depth.shape)
# Out:
# ((79451, 3), (79451, 24))
